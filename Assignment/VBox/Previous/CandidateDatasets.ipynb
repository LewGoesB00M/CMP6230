# %%
import pandas as pd

# %% [markdown]
# # Indian Liver Patient Dataset

# %%
df = pd.read_csv("Data/ilpd.csv",
                       names = ["Age", "Gender", "TB", "DB", "Alkphos", "Sgpt", "Sgot", "TP", "ALB", "AGRatio", "Selector"])

# %%
df.dtypes
# Out:
# Age           int64
# Gender       object
# TB          float64
# DB          float64
# Alkphos       int64
# Sgpt          int64
# Sgot          int64
# TP          float64
# ALB         float64
# AGRatio     float64
# Selector      int64
# dtype: object

# %%
df.describe()
# Out:
#               Age          TB          DB      Alkphos         Sgpt  \
# count  583.000000  583.000000  583.000000   583.000000   583.000000
# mean    44.746141    3.298799    1.486106   290.576329    80.713551
# std     16.189833    6.209522    2.808498   242.937989   182.620356
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.500000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     58.000000    2.600000    1.300000   298.000000    60.500000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               Sgot          TP         ALB     AGRatio    Selector
# count   583.000000  583.000000  583.000000  579.000000  583.000000
# mean    109.910806    6.483190    3.141852    0.947064    1.286449
# std     288.918529    1.085451    0.795519    0.319592    0.452490
# min      10.000000    2.700000    0.900000    0.300000    1.000000
# ...

# %%
df.head()
# Out:
#    Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  AGRatio  Selector
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3     0.90         1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2     0.74         1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3     0.89         1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4     1.00         1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4     0.40         1

# %%
df.isna().sum()
# Out:
# Age         0
# Gender      0
# TB          0
# DB          0
# Alkphos     0
# Sgpt        0
# Sgot        0
# TP          0
# ALB         0
# AGRatio     4
# Selector    0
# dtype: int64

# %%
df[df["AGRatio"].isna()]
# Out:
#      Age  Gender   TB   DB  Alkphos  Sgpt  Sgot   TP  ALB  AGRatio  Selector
# 209   45  Female  0.9  0.3      189    23    33  6.6  3.9      NaN         1
# 241   51    Male  0.8  0.2      230    24    46  6.5  3.1      NaN         1
# 253   35  Female  0.6  0.2      180    12    15  5.2  2.7      NaN         2
# 312   27    Male  1.3  0.6      106    25    54  8.5  4.8      NaN         2

# %% [markdown]
# # Spotify likes dataset

# %%
df_spotifyCSV = pd.read_csv("Data/Spotify/data.csv")

# %%
df_spotifyCSV.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.803  0.6240    7    -6.764     0       0.0477         0.451
# 1         0.762  0.7030   10    -7.951     0       0.3060         0.206
# 2         0.261  0.0149    1   -27.528     1       0.0419         0.992
# 3         0.722  0.7360    3    -6.994     0       0.0585         0.431
# 4         0.787  0.5720    1    -7.516     1       0.2220         0.145
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000734    0.1000   0.6280   95.968       304524               4
# 1          0.000000    0.0912   0.5190  151.329       247178               4
# 2          0.897000    0.1020   0.0382   75.296       286987               4
# 3          0.000001    0.1230   0.5820   89.860       208920               4
# 4          0.000000    0.0753   0.6470  155.117       179413               4
#
#    liked
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1

# %%
df_spotifyCSV.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# liked                 int64
# dtype: object

# %%
df_spotifyCSV.isna().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# liked               0
# dtype: int64

# %%
df_spotifyCSV.describe()
# Out:
#        danceability      energy         key    loudness        mode  \
# count    195.000000  195.000000  195.000000  195.000000  195.000000
# mean       0.636656    0.638431    5.497436   -9.481631    0.538462
# std        0.216614    0.260096    3.415209    6.525086    0.499802
# min        0.130000    0.002400    0.000000  -42.261000    0.000000
# 25%        0.462500    0.533500    2.000000   -9.962000    0.000000
# 50%        0.705000    0.659000    6.000000   -7.766000    1.000000
# 75%        0.799000    0.837500    8.000000   -5.829000    1.000000
# max        0.946000    0.996000   11.000000   -2.336000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   195.000000    195.000000        195.000000  195.000000  195.000000
# mean      0.148957      0.319093          0.192337    0.148455    0.493632
# std       0.120414      0.320782          0.346226    0.105975    0.267695
# ...

# %%
df_spotifyCSV.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_spotifyCSV.head()
#
# NameError: name 'df_spotifyCSV' is not defined

# %% [markdown]
# ## Dislikes.json

# %%
df_spotifyDislikes = pd.read_json("Data/Spotify/dislike.json")

# %%
df_spotifyDislikes.head()
# Out:
#                                       audio_features
# 0  {'danceability': 0.357, 'energy': 0.98, 'key':...
# 1  {'danceability': 0.446, 'energy': 0.977, 'key'...
# 2  {'danceability': 0.291, 'energy': 0.98, 'key':...
# 3  {'danceability': 0.462, 'energy': 0.974, 'key'...
# 4  {'danceability': 0.338, 'energy': 0.988, 'key'...

# %%
df_spotifyDislikes = pd.json_normalize(df_spotifyDislikes["audio_features"])

# %%
df_spotifyDislikes.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.357   0.980    6    -6.835     1       0.0790      0.000052
# 1         0.446   0.977   10    -5.036     0       0.0781      0.000535
# 2         0.291   0.980    1    -5.138     1       0.1530      0.001270
# 3         0.462   0.974    1    -5.820     1       0.0816      0.000029
# 4         0.338   0.988    8    -7.290     0       0.0865      0.000083
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0             0.843    0.0768    0.368   96.969  audio_features
# 1             0.472    0.1050    0.339  172.059  audio_features
# 2             0.091    0.1020    0.257   79.792  audio_features
# 3             0.723    0.0751    0.399  107.877  audio_features
# 4             0.833    0.0377    0.449   99.046  audio_features
#
#                        id                                   uri  \
# 0  4pFC6tuWErxbO61oFFq3BQ  spotify:track:4pFC6tuWErxbO61oFFq3BQ
# ...

# %%
df_spotifyDislikes.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
df_spotifyDislikes.isna().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %% [markdown]
# # Loan Approval Classification Dataset

# %%
df_loan = pd.read_csv("Data/loan_data.csv")
df_loan.dtypes
# Out:
# person_age                        float64
# person_gender                      object
# person_education                   object
# person_income                     float64
# person_emp_exp                      int64
# person_home_ownership              object
# loan_amnt                         float64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length        float64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# dtype: object

# %%
df_loan.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
df_loan.isna().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
# person_age is a float column, though there aren't any decimal values in it.
# In preprocessing, this should therefore be converted to an integer.
df_loan[df_loan["person_age"] % 1 != 0]
# Out:
# Empty DataFrame
# Columns: [person_age, person_gender, person_education, person_income, person_emp_exp, person_home_ownership, loan_amnt, loan_intent, loan_int_rate, loan_percent_income, cb_person_cred_hist_length, credit_score, previous_loan_defaults_on_file, loan_status]
# Index: []

# %%
df_loan["loan_status"].value_counts()
# Out:
# loan_status
# 0    35000
# 1    10000
# Name: count, dtype: int64
